# %% [markdown]
# <a href="https://colab.research.google.com/github/atfan7/Probability-and-Statistics-Projects/blob/main/T_Test_Sachin_dataset_and_Covid_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from scipy.stats import norm
from scipy.stats import ttest_1samp, ttest_ind
from scipy.stats import ttest_rel

# %%
#T-test

# %%
#Cricket

# %%
from google.colab import files
data=files.upload()
# Out:
#      <input type="file" id="files-6bf83dea-153b-445b-9245-409cbb4b7d58" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6bf83dea-153b-445b-9245-409cbb4b7d58">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv("Sachin_ODI.csv")

# %%
df.head()
# Out:
#    runs  NotOut mins  bf  fours  sixes      sr  Inns           Opp    Ground  \
# 0    13       0   30  15      3      0   86.66     1   New Zealand    Napier
# 1    37       0   75  51      3      1   72.54     2  South Africa  Hamilton
# 2    47       0   65  40      7      0  117.50     2     Australia   Dunedin
# 3    48       0   37  30      9      1  160.00     2    Bangladesh   Sharjah
# 4     4       0   13   9      1      0   44.44     2      Pakistan   Sharjah
#
#          Date        Winner    Won  century
# 0  1995-02-16   New Zealand  False    False
# 1  1995-02-18  South Africa  False    False
# 2  1995-02-22         India   True    False
# 3  1995-04-05         India   True    False
# 4  1995-04-07      Pakistan  False    False

# %%
#Batting pattern in first and second innings

# %%
df.groupby("Inns")["runs"].mean()
# Out:
# Inns
# 1    46.670588
# 2    40.173684
# Name: runs, dtype: float64

# %%
df_first_innings = df[df["Inns"]==1]
df_second_innings = df[df["Inns"]==2]

# %%
# H0: mu1 = mu2
# Ha : mu1 > mu2

alpha = 0.05
t_stat, p_value = ttest_ind(df_first_innings["runs"], df_second_innings["runs"], alternative="greater")
print(p_value)
# Out:
# 0.07241862097379981

# %%
if p_value < alpha:
    print("Reject H0")
    print("First innings is better")
else:
    print("Fail to reject H0")
    print("Difference we see is just chance")
# Out:
# Fail to reject H0
# Difference we see is just chance

# %%
#Victory Vs Defeat

# %%
df.groupby("Won")["runs"].mean()
# Out:
# Won
# False    35.130682
# True     51.000000
# Name: runs, dtype: float64

# %%
df_lost = df[df["Won"]==False] #mu1
df_won = df[df["Won"]==True] #mu2

# %%
# H0: mu1 = mu2
# Ha : mu1 < mu2

alpha = 0.05

# %%
test_stat, p_value = ttest_ind(df_lost["runs"],df_won["runs"], alternative="less")

#Ha : mu1 > mu2
#test_stat, p_value = ttest_ind(df_won["runs"],df_lost["runs"], alternative="greater")

print(p_value)

if p_value < alpha:
    print("Reject H0")
else:
    print("Fail to reject")
# Out:
# 0.00016353077486826558
# Reject H0

# %%
#Drug recovery : two competing drugs for covid.

# %%
data=files.upload()
# Out:
#      <input type="file" id="files-d9a2f9b0-6e13-4181-a101-6d3d1756284f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d9a2f9b0-6e13-4181-a101-6d3d1756284f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
d1 = pd.read_csv("drug_1_recovery.csv")
d1
# Out:
#       drug_1
# 0   8.824208
# 1   7.477745
# 2   7.557121
# 3   7.981314
# 4   6.827716
# ..       ...
# 95  6.890506
# 96  7.725759
# 97  6.848016
# 98  7.969997
# 99  7.104209
#
# [100 rows x 1 columns]

# %%
d1.mean()
# Out:
# drug_1    7.104917
# dtype: float64

# %%
d2 = pd.read_csv("drug_2_recovery.csv")

# %%
d2
# Out:
#        drug_2
# 0    9.565974
# 1    7.492915
# 2    8.738418
# 3    7.635235
# 4    4.125593
# ..        ...
# 115  7.861993
# 116  8.233510
# 117  5.876257
# 118  7.789454
# 119  8.836125
#
# [120 rows x 1 columns]

# %%
d2.mean()
# Out:
# drug_2    8.073423
# dtype: float64

# %%
# H0: mu1 = mu2
# Ha: mu1 < mu2

t_stat, p_value = ttest_ind(d1, d2, alternative="less")
print(p_value)
if p_value < 0.05:
    print("Reject H0")
else:
    print("Fail to reject H0")
# Out:
# [1.27713574e-07]
# Reject H0

# %%
#Paired T-Test

# %% [markdown]
# Will problem solving sessions help students?
#
# Test 1: Before the session
#
# Test 2: After the session

# %%
data=files.upload()
# Out:
#      <input type="file" id="files-a5b89816-f8e0-438d-bdcf-e45c52a1656e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a5b89816-f8e0-438d-bdcf-e45c52a1656e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df_ps = pd.read_csv("problem_solving copy.csv")

# %%
len(df_ps)
# Out:
# 137

# %%
df_ps.head()
# Out:
#    id  test_1  test_2
# 0   0      40      38
# 1   1      49      44
# 2   2      65      69
# 3   3      59      63
# 4   4      44      43

# %%
df_ps.describe()
# Out:
#                id      test_1      test_2
# count  137.000000  137.000000  137.000000
# mean    68.000000   60.489051   62.430657
# std     39.692569   17.080311   17.516293
# min      0.000000   30.000000   27.000000
# 25%     34.000000   46.000000   48.000000
# 50%     68.000000   59.000000   62.000000
# 75%    102.000000   75.000000   77.000000
# max    136.000000   89.000000   96.000000

# %%
# H0: Problem solving has no effect
# Ha: Problem solving had an effect

# %%
ttest_rel(df_ps["test_1"] , df_ps["test_2"])
# Out:
# TtestResult(statistic=-5.502886353508166, pvalue=1.795840353792313e-07, df=136)

# %%
# H0: Problem solving has no effect
# Ha: Problem solving improved the scores (<)
ttest_rel(df_ps["test_1"], df_ps["test_2"], alternative="less")
# Out:
# TtestResult(statistic=-5.502886353508166, pvalue=8.979201768961566e-08, df=136)

# %%
# H0: Problem solving has no effect
# Ha: Problem solving deteriorated the scores (>)
ttest_rel(df_ps["test_1"], df_ps["test_2"], alternative="greater")
# Out:
# TtestResult(statistic=-5.502886353508166, pvalue=0.9999999102079823, df=136)
